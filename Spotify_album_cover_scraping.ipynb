# %% [markdown]
# ### This notebook is to scrape the album cover of the 20k sampled songs

# %%
# === 0) Imports & setup ===
import os, io, time, math, requests
import pandas as pd
from pathlib import Path
from PIL import Image
from tqdm import tqdm

# Spotify
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Optional: set your credentials here or in your env
os.environ['SPOTIPY_CLIENT_ID'] = '####################'
os.environ['SPOTIPY_CLIENT_SECRET'] = '######################'

ALBUM_OUT_DIR = Path("image_data/album_cover")
ALBUM_OUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
# Load the data 
spotify_train_20k = pd.read_csv('spotify_data/spotify_train_20k.csv')
spotify_test_20k = pd.read_csv('spotify_data/spotify_test_20k.csv')


spotify_sample_20k = pd.concat([spotify_train_20k, spotify_test_20k])

# try on the first 5 songs (comment this when trying to scale)
# spotify_sample_20k = spotify_sample_20k.head(5)

# %%
# === 1) Helpers ===
def init_spotify():
    return spotipy.Spotify(
        auth_manager=SpotifyClientCredentials(),
        requests_timeout=20,
        retries=3
    )

def pick_best_image(images, prefer_min_px=640):
    if not images:
        return None
    images_sorted = sorted(images, key=lambda im: min(im.get("height",0), im.get("width",0)))
    for im in images_sorted:
        if min(im.get("height",0), im.get("width",0)) >= prefer_min_px:
            return im
    return images_sorted[-1]

def download_image(url, out_path):
    try:
        r = requests.get(url, timeout=20)
        r.raise_for_status()
        img = Image.open(io.BytesIO(r.content)).convert("RGB")
        out_path.parent.mkdir(parents=True, exist_ok=True)
        img.save(out_path, format="JPEG", quality=92)
        return img.size  # (w,h)
    except Exception:
        return None

def get_deezer_cover_from_isrc(isrc):
    try:
        r = requests.get("https://api.deezer.com/search", params={"q": f"isrc:{isrc}"}, timeout=15)
        r.raise_for_status()
        data = r.json().get("data", [])
        if not data:
            return None
        alb = data[0].get("album", {}) or {}
        return alb.get("cover_xl") or alb.get("cover_big") or alb.get("cover_medium") or alb.get("cover")
    except Exception:
        return None

def fetch_album_covers_spotify(track_ids, out_dir=ALBUM_OUT_DIR, batch_size=50, sleep_s=0.0):
    """Return DF with: track_id, track_name, artist_name, album_name, release_date,
       album_cover_url, album_cover_path, cover_width, cover_height, isrc
    """
    sp = init_spotify()
    rows = []
    # dedupe while preserving order
    seen = set()
    track_ids = [tid for tid in track_ids if (tid and not (tid in seen or seen.add(tid)))]

    for i in tqdm(range(0, len(track_ids), batch_size), desc="Spotify covers"):
        chunk = track_ids[i:i+batch_size]
        try:
            resp = sp.tracks(chunk) or {}
            tracks = resp.get("tracks", []) or []
        except Exception:
            tracks = []

        for t in tracks:
            if not t:
                continue
            tid   = t.get("id")
            tname = t.get("name")
            aname = ", ".join([a["name"] for a in t.get("artists", [])]) or None
            alb   = t.get("album", {}) or {}
            an    = alb.get("name")
            rd    = alb.get("release_date")
            images = alb.get("images", []) or []
            isrc  = (t.get("external_ids") or {}).get("isrc")

            chosen = pick_best_image(images, prefer_min_px=640)
            url    = chosen.get("url") if chosen else None

            cover_path = None
            w = h = None
            if url and tid:
                out_path = out_dir / f"{tid}.jpg"
                size = download_image(url, out_path)
                if size:
                    w, h = size
                    cover_path = str(out_path)

            rows.append({
                "track_id": tid,
                "track_name": tname,
                "artist_name": aname,
                "album_name": an,
                "release_date": rd,
                "album_cover_url": url,
                "album_cover_path": cover_path,
                "cover_width": w,
                "cover_height": h,
                "isrc": isrc,
            })

        if sleep_s > 0:
            time.sleep(sleep_s)

    return pd.DataFrame(rows)

def fetch_album_covers_deezer_isrc(isrc_list, out_dir=ALBUM_OUT_DIR):
    rows = []
    for isrc in tqdm(isrc_list, desc="Deezer fallback"):
        url = get_deezer_cover_from_isrc(isrc)
        w = h = None
        cover_path = None
        if url:
            out_path = out_dir / f"{isrc}.jpg"
            size = download_image(url, out_path)
            if size:
                w, h = size
                cover_path = str(out_path)
        rows.append({
            "isrc": isrc,
            "deezer_cover_url": url,
            "deezer_cover_path": cover_path,
            "deezer_cover_width": w,
            "deezer_cover_height": h,
        })
    return pd.DataFrame(rows)

# %%
# === 2) Run on your df_sample_10k ===
# Required column: 'track_id'
track_ids_all = (
    spotify_sample_20k["track_id"]
    .dropna()
    .astype(str)
    .str.strip()
    .unique()
    .tolist()
)

covers_spotify = fetch_album_covers_spotify(track_ids_all, out_dir=ALBUM_OUT_DIR)

# Deezer fallback for rows still missing local image BUT having ISRC
need_fallback = covers_spotify[
    covers_spotify["album_cover_path"].isna() & covers_spotify["isrc"].notna()
]["isrc"].dropna().unique().tolist()

if len(need_fallback) > 0:
    deezer_df = fetch_album_covers_deezer_isrc(need_fallback, out_dir=ALBUM_OUT_DIR)
    # Join Deezer results back
    covers_spotify = covers_spotify.merge(deezer_df, on="isrc", how="left")
    # fill missing path/url/size from deezer
    covers_spotify["album_cover_path"] = covers_spotify["album_cover_path"].fillna(covers_spotify["deezer_cover_path"])
    covers_spotify["album_cover_url"]  = covers_spotify["album_cover_url"].fillna(covers_spotify["deezer_cover_url"])
    covers_spotify["cover_width"]  = covers_spotify["cover_width"].fillna(covers_spotify["deezer_cover_width"])
    covers_spotify["cover_height"] = covers_spotify["cover_height"].fillna(covers_spotify["deezer_cover_height"])
    covers_spotify.drop(columns=[c for c in covers_spotify.columns if c.startswith("deezer_")], inplace=True, errors="ignore")
# Out:
# Spotify covers: 100%|██████████| 430/430 [1:03:13<00:00,  8.82s/it]
# Deezer fallback: 100%|██████████| 2/2 [00:00<00:00,  4.62it/s]
# C:\Users\brian\AppData\Local\Temp\ipykernel_38848\3178843486.py:26: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   covers_spotify["cover_width"]  = covers_spotify["cover_width"].fillna(covers_spotify["deezer_cover_width"])
# C:\Users\brian\AppData\Local\Temp\ipykernel_38848\3178843486.py:27: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   covers_spotify["cover_height"] = covers_spotify["cover_height"].fillna(covers_spotify["deezer_cover_height"])

# %%
# === 3) Merge back to your 10k sample & save a manifest ===
cols_keep = [
    "track_id","track_name","artist_name","album_name","release_date",
    "isrc","album_cover_url","album_cover_path","cover_width","cover_height"
]
covers_spotify = covers_spotify[cols_keep].drop_duplicates("track_id")

spotify_sample_20k_with_covers = spotify_sample_20k.merge(covers_spotify, on="track_id", how="left")

# Save a clean manifest (CSV)
MANIFEST_PATH = Path("image_data/spotify_album_cover_manifest.csv")
MANIFEST_PATH.parent.mkdir(parents=True, exist_ok=True)
spotify_sample_20k_with_covers.to_csv(MANIFEST_PATH, index=False)

# %%
# === 4) Quick summary ===
total = len(spotify_sample_20k_with_covers)
saved = spotify_sample_20k_with_covers["album_cover_path"].notna().sum()
print(f"Album covers saved locally: {saved}/{total} ({saved/total:.1%})")
print(f"Manifest: {MANIFEST_PATH}")
spotify_sample_20k_with_covers.head(5)
# Out:
# Album covers saved locally: 21444/21500 (99.7%)
# Manifest: image_data\spotify_album_cover_manifest.csv
#                  track_id       artist_name_x           track_name_x      pop  \
# 0  0EWF6VAofw5mnG0pUzcV3U              Thelem          False Imprint     flop
# 1  5i6oXQ079nFUszXyRZu4uY           Audiojack  6EQUJ5 - Original Mix  regular
# 2  76Nd1pesCxNehpUl4k63I4  The Little Willies       Easy As The Rain  regular
# 3  6ZthdsKjWtiCxnxbhs74vF               Gunna          Drip or Drown      hit
# 4  4FcknXDJ8yW2QYUl0cm6uJ          Imran Khan                 Bewafa      hit
#
#   artist_tier  year  danceability  energy  key  loudness  ...  time_signature  \
# 0           B  2013         0.672   0.567    0   -10.392  ...               4
# 1           A  2017         0.805   0.620    4    -8.551  ...               4
# 2           A  2006         0.576   0.163    2   -14.544  ...               4
# 3           A  2017         0.952   0.478    5    -8.520  ...               4
# 4           B  2009         0.704   0.563    4    -4.739  ...               4
#
#             track_name_y       artist_name_y          album_name  \
# 0          False Imprint              Thelem       Bring Me Down
# 1  6EQUJ5 - Original Mix           Audiojack        Implications
# 2       Easy As The Rain  The Little Willies  The Little Willies
# 3          Drip or Drown               Gunna       Drip or Drown
# 4                 Bewafa          Imran Khan              Bewafa
#
#    release_date          isrc  \
# 0    2013-10-28  NZIN01200046
# 1    2017-06-09  GB7NR1718103
# 2    2006-01-01  USBN20500480
# 3    2017-11-30  QZ5FA1751845
# 4    2009-07-27  GBRCG0900013
#
#                                      album_cover_url  \
# 0  https://i.scdn.co/image/ab67616d0000b273315fdf...
# 1  https://i.scdn.co/image/ab67616d0000b2731329eb...
# 2  https://i.scdn.co/image/ab67616d0000b2734d7a43...
# 3  https://i.scdn.co/image/ab67616d0000b273340cf6...
# 4  https://i.scdn.co/image/ab67616d0000b273a9eec0...
#
#                                     album_cover_path  cover_width cover_height
# 0  image_data\album_cover\0EWF6VAofw5mnG0pUzcV3U.jpg        640.0        640.0
# 1  image_data\album_cover\5i6oXQ079nFUszXyRZu4uY.jpg        640.0        640.0
# 2  image_data\album_cover\76Nd1pesCxNehpUl4k63I4.jpg        640.0        640.0
# 3  image_data\album_cover\6ZthdsKjWtiCxnxbhs74vF.jpg        640.0        640.0
# 4  image_data\album_cover\4FcknXDJ8yW2QYUl0cm6uJ.jpg        640.0        640.0
#
# [5 rows x 28 columns]

# %%
# find the rows in spotify_sample_20k_with_covers that have no album cover path
spotify_sample_20k_with_covers[spotify_sample_20k_with_covers["album_cover_path"].isna()]
# Out:
#                      track_id              artist_name_x  \
# 16016  5W7DOVGQLTigu09afW7QMT           Sidhu Moose Wala
# 18609  7ldMHsWJkczg8QqaJcSVjE                   puremind
# 18905  1m1apFo0NAaaw7h9NNoG6R                   Lawrence
# 19136  0QUxWlGwGeV9MZhwgBvTmV              Alberto Gomez
# 19488  3FUBAPKKO6OHkl2fexm0yn               Pxlish Beatz
# 20200  0CCidxt43DTmHtvq465p1L                   The Body
# 20201  0nRFROGcDtNFntI8ZtHT5z                    Solange
# 20202  5HP9LwDRT5FGOokrN1HnZ3          Mark Roswell Trio
# 20203  3RCTsZxDQZp6dz7QGJNr3a            Lata Mangeshkar
# 20204  1MpCaOeUWhox2Fgigbe1cL                    Beyoncé
# 20205  1TWOChh94XuC6P66d8Oy61     The Last Days Of Jesus
# 20206  4KHSvVJBteqf6XuUDlbltp                  JP Cooper
# 20207  6Zw25LRLP0j0MsezDFIUM4           Hugo & Guilherme
# 20208  23Fjo8LJKqDb8d1i74deDq                 The Unseen
# 20209  3hFUDnpeirNo2FjZyOZOk9                  Amber Run
# 20210  0u6ioCIZsRiC8xIfYWyD1m                  Gabrielle
# 20211  2OXdm1RUTezuALGS0dk1rQ                  Silk Boss
# 20212  31imJBbJO6LCf4hWowc8DZ                   Dj Thera
# 20213  2umP2MjX54xdneqHLISHMo            Kaspiyskiy Gruz
# 20214  5W1Uc1b5dmsqrfF1GzShGs          Henrik Lindstrand
# 20215  3n6KpoOrkhTPO2LuKmtSAy       Blind Willie Johnson
# 20216  3ENX5VYn6FNiDSPFWmR2vm                    Matroda
# 20217  5PSrROgdt1hrLu6I5P44GD               David Healer
# 20218  3Wc4jQhzto9iZehUirrzcM             Kelly Clarkson
# 20219  4mSOngutH6P5gWYurvmR3W                    Erick B
# 20220  2cYwZnsAzNuvSNYucLsAEm             Jubin Nautiyal
# 20221  2CcDCtAajVcNe0F8u6N5Pc                 SATV Music
# 20222  1YO1vzBy6y44sosMHviv0S           Electric Callboy
# 20223  6UF6eZMHeDMo9ZDHoWxr3d               Rahul Sharma
# 20224  5rbpqTgrUXwr8HXnh0CWle                Adam Jensen
# 20225  0EYjR54ZN4ufLEBgs6QOwt                 Ulaan Khol
# 20226  0PJqlrV6SR5RzM0M8tdLWw         Christian Lindberg
# 20227  124xiigBZpxUxs9pEXB1vU                     88GLAM
# 20228  4cmHMhnZr9zm0Z9O0W5D2C            Jackie Brenston
# 20229  4PeGUBERD8qDn6oP3XmEuQ                  KiNG MALA
# 20230  6xu7oJW0hqJfMk2RpJYy8s        Anna von Hausswolff
# 20231  2r2l2KmLnaULSmaeB7Df8b                   Lykke Li
# 20232  7K1tCc3d1HGD2znVvmLil5                Yo La Tengo
# 20233  7kSQCzt3Ts5slN0fH4BwED          Oceans Ate Alaska
# 20234  34QYVfarR4z68eFzTY9w0J         Sleep Fruits Music
# 20235  6haYUzGsx9YvQl1k3CoUZU               Darkest Hour
# 20236  3Q90tQQevxxirs4vcIcMkc    Five Finger Death Punch
# 20237  40Xs0mrXcvTiUhLxIah4mV                Age of Rage
# 20238  0qwb2CmZcHBGi3yhywTLSs               Los Master's
# 20239  2Bk4WrSt1FhZuc100UpFqb               Hollow Front
# 20240  2icvQWarn6VW4qsvjVSNNE               Lydia Barnes
# 20241  6fWYHjwem8hhnPBelFZi9c           Shaddaï Ndombaxe
# 20242  1Djmp0UgkkeOxolkChYXRe                  DJ Pierre
# 20243  7Ggjpot1h2KqHLsKGhgGH2               Stalk Ashley
# 20244  7mI5WucYY3gmmJzTMkhB2X      Johann Sebastian Bach
# 20245  5EhgQ5vOMCO9rudLFO8dls                Summer 2000
# 20246  2SOaNPt2zuIMBZAicHGlTC          Arms and Sleepers
# 20247  5Ma7gdR26nKGwGPOVobufm  Los Auténticos Decadentes
# 20248  3ugOZB8W9CGQQNVH6FMnqU            Alberto Vazquez
# 20249  2R0CAQ9MMFl23yk4FaD4kE                The Prophet
# 21036  6IrjIvxxqZuidkENjW72Q5                 Hoàng Dũng
#
#                                             track_name_x      pop artist_tier  \
# 16016                                                295      hit           C
# 18609                                         Malo Tebya  regular           U
# 18905                                    Gilbert [Mixed]  regular           A
# 19136                                     Uno - Orquesta     flop           U
# 19488                    Malo Tebya - Pxlish Beatz Remix  regular           U
# 20200                               Conspiracy Privilege     flop           A
# 20201                        Twinkle Twinkle Little Star     flop           S
# 20202                                          Blue Moon  regular           U
# 20203                        Mai Chali Mai Chali (Remix)     flop           A
# 20204                                      I'M THAT GIRL  regular           S
# 20205                  Dark Side of My Mind - :ON BLACK:     flop           U
# 20206                                          Too Close  regular           A
# 20207                                Mal Feito - Ao Vivo  regular           U
# 20208                         Your Failure Is My Revenge     flop           A
# 20209                                     The Last Dance  regular           A
# 20210                                             Dreams     flop           S
# 20211                                    Where Silk Gone  regular           U
# 20212                                    Tranceportation     flop           U
# 20213                                 Осторожно Окрашено  regular           U
# 20214                                               Hvid     flop           B
# 20215                  You'll Need Somebody on Your Bond     flop           A
# 20216                       Gimme Some Keys - TONG Remix  regular           B
# 20217       When You Wish Upon A Star (From "Pinocchio")  regular           U
# 20218                           Happier Than Ever - Edit  regular           S
# 20219                                          Otra Vida  regular           U
# 20220                                         Aise Kaise  regular           C
# 20221                                       Give Me More     flop           U
# 20222                     Fuckboi (feat. Conquer Divide)  regular           U
# 20223                    Eternity_ Sunset In Kanyakumari     flop           B
# 20224                        Bullet with Your Name on It  regular           A
# 20225                                           Rain Tea  regular           B
# 20226                                         Loneliness     flop           B
# 20227                                    Urgent Messages     flop           A
# 20228                                         Starvation     flop           F
# 20229                                             sloppy  regular           U
# 20230                    Pomperipossa - Live at Montreux     flop           A
# 20231                                        HAPPY HURTS  regular           S
# 20232                                  This Stupid World  regular           S
# 20233                                     Shallow Graves  regular           A
# 20234                            Fall Asleep Fast, Pt. 6  regular           U
# 20235                         For the Soul of the Savior  regular           S
# 20236                                         All I Know  regular           S
# 20237                                         Demonition     flop           U
# 20238                                       Mi Conuquito     flop           U
# 20239                                      Self Sabotage  regular           B
# 20240                                           Marigold  regular           U
# 20241                                          Comme toi  regular           U
# 20242                             Love Desire - Club Mix     flop           A
# 20243                                         Earthquake  regular           U
# 20244  Bach, JS: Orchestral Suite No. 3 in D Major, B...  regular           S
# 20245                  gcn_startup_screen_glitch_art.sav     flop           U
# 20246          maybe this world is another planet's hell  regular           A
# 20247                                           Bailando  regular           A
# 20248                                      Victima de Ti     flop           U
# 20249                                H3Y! - Revive Remix     flop           A
# 21036                               tình em là đại dương  regular           F
#
#        year  danceability   energy  key  loudness  ...  time_signature  \
# 16016  2021         0.557  0.79400   11    -5.698  ...               4
# 18609  2022         0.570  0.92000    1    -5.348  ...               4
# 18905  2023         0.631  0.39200    1   -16.066  ...               4
# 19136  2023         0.521  0.14900    3    -8.607  ...               3
# 19488  2022         0.402  0.79600    7    -6.887  ...               4
# 20200  2022         0.334  0.88600    2    -4.593  ...               4
# 20201  2023         0.811  0.62600   11    -4.775  ...               4
# 20202  2023         0.473  0.13200    3   -19.769  ...               4
# 20203  2023         0.645  0.72400    9    -7.443  ...               4
# 20204  2022         0.554  0.53500    5    -8.959  ...               4
# 20205  2023         0.303  0.81500   11    -3.999  ...               4
# 20206  2022         0.642  0.73400   11    -4.979  ...               4
# 20207  2022         0.732  0.83100    0    -3.791  ...               4
# 20208  2022         0.266  0.98000    4    -0.813  ...               4
# 20209  2023         0.254  0.11400    6   -12.459  ...               3
# 20210  2023         0.619  0.71900    9    -8.502  ...               4
# 20211  2023         0.598  0.68500    1    -6.133  ...               4
# 20212  2023         0.526  0.89100    5    -6.999  ...               4
# 20213  2023         0.733  0.62300   10    -3.468  ...               4
# 20214  2023         0.314  0.04090    6   -23.383  ...               3
# 20215  2023         0.665  0.19300    6   -11.135  ...               4
# 20216  2022         0.653  0.97300   11    -4.396  ...               4
# 20217  2022         0.705  0.01360    0   -28.106  ...               4
# 20218  2022         0.480  0.76800    3    -4.158  ...               3
# 20219  2023         0.680  0.67400    8    -6.014  ...               3
# 20220  2023         0.735  0.54600    7   -10.208  ...               4
# 20221  2023         0.735  0.72200    2    -8.022  ...               4
# 20222  2022         0.536  0.75900    8    -9.521  ...               4
# 20223  2023         0.468  0.50100    2   -12.970  ...               4
# 20224  2022         0.761  0.66200    6    -7.302  ...               4
# 20225  2023         0.430  0.54200    6   -11.006  ...               4
# 20226  2023         0.341  0.00769    7   -32.930  ...               3
# 20227  2023         0.811  0.62200    1    -5.977  ...               4
# 20228  2023         0.438  0.85200    1    -4.610  ...               4
# 20229  2022         0.711  0.42700    6    -7.558  ...               4
# 20230  2022         0.187  0.76000    3    -9.745  ...               4
# 20231  2022         0.261  0.45200    7    -9.157  ...               4
# 20232  2023         0.291  0.49600    2    -7.736  ...               5
# 20233  2022         0.525  0.94400   11    -4.093  ...               4
# 20234  2022         0.145  0.01430    9   -35.224  ...               4
# 20235  2022         0.192  0.98400    8    -6.058  ...               4
# 20236  2022         0.486  0.91100    2    -5.214  ...               3
# 20237  2022         0.453  0.98100    7    -2.850  ...               4
# 20238  2022         0.713  0.74600    7   -11.854  ...               4
# 20239  2022         0.515  0.97900    1    -3.343  ...               4
# 20240  2023         0.388  0.21900    2   -27.549  ...               4
# 20241  2022         0.666  0.72500   10    -6.041  ...               4
# 20242  2022         0.805  0.56300   10    -8.658  ...               4
# 20243  2023         0.848  0.67600    1    -9.611  ...               4
# 20244  2023         0.418  0.36200    1   -15.997  ...               4
# 20245  2023         0.285  0.22200    7   -19.104  ...               4
# 20246  2023         0.182  0.13600    2   -23.605  ...               4
# 20247  2022         0.746  0.84900    9    -5.709  ...               4
# 20248  2023         0.308  0.47600    2    -7.440  ...               4
# 20249  2023         0.543  0.95500   11    -2.375  ...               4
# 21036  2022         0.656  0.35800    9    -8.149  ...               4
#
#           track_name_y  artist_name_y  \
# 16016                            None
# 18609                            None
# 18905  Gilbert [Mixed]       Lawrence
# 19136   Uno - Orquesta  Alberto Gomez
# 19488                            None
# 20200              NaN            NaN
# 20201              NaN            NaN
# 20202              NaN            NaN
# 20203              NaN            NaN
# 20204              NaN            NaN
# 20205              NaN            NaN
# 20206              NaN            NaN
# 20207              NaN            NaN
# 20208              NaN            NaN
# 20209              NaN            NaN
# 20210              NaN            NaN
# 20211              NaN            NaN
# 20212              NaN            NaN
# 20213              NaN            NaN
# 20214              NaN            NaN
# 20215              NaN            NaN
# 20216              NaN            NaN
# 20217              NaN            NaN
# 20218              NaN            NaN
# 20219              NaN            NaN
# 20220              NaN            NaN
# 20221              NaN            NaN
# 20222              NaN            NaN
# 20223              NaN            NaN
# 20224              NaN            NaN
# 20225              NaN            NaN
# 20226              NaN            NaN
# 20227              NaN            NaN
# 20228              NaN            NaN
# 20229              NaN            NaN
# 20230              NaN            NaN
# 20231              NaN            NaN
# 20232              NaN            NaN
# 20233              NaN            NaN
# 20234              NaN            NaN
# 20235              NaN            NaN
# 20236              NaN            NaN
# 20237              NaN            NaN
# 20238              NaN            NaN
# 20239              NaN            NaN
# 20240              NaN            NaN
# 20241              NaN            NaN
# 20242              NaN            NaN
# 20243              NaN            NaN
# 20244              NaN            NaN
# 20245              NaN            NaN
# 20246              NaN            NaN
# 20247              NaN            NaN
# 20248              NaN            NaN
# 20249              NaN            NaN
# 21036                            None
#
#                                       album_name  release_date          isrc  \
# 16016                                                     0000          None
# 18609                                                     0000          None
# 18905               Connecting The Dots (DJ Mix)    2023-01-13  DEU672300078
# 19136  Zorzales de Antaño, Vol. 1: Alberto Gomez    2023-01-25  QM4TW2301517
# 19488                                                     0000          None
# 20200                                        NaN           NaN           NaN
# 20201                                        NaN           NaN           NaN
# 20202                                        NaN           NaN           NaN
# 20203                                        NaN           NaN           NaN
# 20204                                        NaN           NaN           NaN
# 20205                                        NaN           NaN           NaN
# 20206                                        NaN           NaN           NaN
# 20207                                        NaN           NaN           NaN
# 20208                                        NaN           NaN           NaN
# 20209                                        NaN           NaN           NaN
# 20210                                        NaN           NaN           NaN
# 20211                                        NaN           NaN           NaN
# 20212                                        NaN           NaN           NaN
# 20213                                        NaN           NaN           NaN
# 20214                                        NaN           NaN           NaN
# 20215                                        NaN           NaN           NaN
# 20216                                        NaN           NaN           NaN
# 20217                                        NaN           NaN           NaN
# 20218                                        NaN           NaN           NaN
# 20219                                        NaN           NaN           NaN
# 20220                                        NaN           NaN           NaN
# 20221                                        NaN           NaN           NaN
# 20222                                        NaN           NaN           NaN
# 20223                                        NaN           NaN           NaN
# 20224                                        NaN           NaN           NaN
# 20225                                        NaN           NaN           NaN
# 20226                                        NaN           NaN           NaN
# 20227                                        NaN           NaN           NaN
# 20228                                        NaN           NaN           NaN
# 20229                                        NaN           NaN           NaN
# 20230                                        NaN           NaN           NaN
# 20231                                        NaN           NaN           NaN
# 20232                                        NaN           NaN           NaN
# 20233                                        NaN           NaN           NaN
# 20234                                        NaN           NaN           NaN
# 20235                                        NaN           NaN           NaN
# 20236                                        NaN           NaN           NaN
# 20237                                        NaN           NaN           NaN
# 20238                                        NaN           NaN           NaN
# 20239                                        NaN           NaN           NaN
# 20240                                        NaN           NaN           NaN
# 20241                                        NaN           NaN           NaN
# 20242                                        NaN           NaN           NaN
# 20243                                        NaN           NaN           NaN
# 20244                                        NaN           NaN           NaN
# 20245                                        NaN           NaN           NaN
# 20246                                        NaN           NaN           NaN
# 20247                                        NaN           NaN           NaN
# 20248                                        NaN           NaN           NaN
# 20249                                        NaN           NaN           NaN
# 21036                                                     0000          None
#
#                                          album_cover_url  album_cover_path  \
# 16016                                                NaN               NaN
# 18609                                                NaN               NaN
# 18905  https://i.scdn.co/image/ab67616d0000b2732992fb...              None
# 19136                                               None              None
# 19488                                                NaN               NaN
# 20200                                                NaN               NaN
# 20201                                                NaN               NaN
# 20202                                                NaN               NaN
# 20203                                                NaN               NaN
# 20204                                                NaN               NaN
# 20205                                                NaN               NaN
# 20206                                                NaN               NaN
# 20207                                                NaN               NaN
# 20208                                                NaN               NaN
# 20209                                                NaN               NaN
# 20210                                                NaN               NaN
# 20211                                                NaN               NaN
# 20212                                                NaN               NaN
# 20213                                                NaN               NaN
# 20214                                                NaN               NaN
# 20215                                                NaN               NaN
# 20216                                                NaN               NaN
# 20217                                                NaN               NaN
# 20218                                                NaN               NaN
# 20219                                                NaN               NaN
# 20220                                                NaN               NaN
# 20221                                                NaN               NaN
# 20222                                                NaN               NaN
# 20223                                                NaN               NaN
# 20224                                                NaN               NaN
# 20225                                                NaN               NaN
# 20226                                                NaN               NaN
# 20227                                                NaN               NaN
# 20228                                                NaN               NaN
# 20229                                                NaN               NaN
# 20230                                                NaN               NaN
# 20231                                                NaN               NaN
# 20232                                                NaN               NaN
# 20233                                                NaN               NaN
# 20234                                                NaN               NaN
# 20235                                                NaN               NaN
# 20236                                                NaN               NaN
# 20237                                                NaN               NaN
# 20238                                                NaN               NaN
# 20239                                                NaN               NaN
# 20240                                                NaN               NaN
# 20241                                                NaN               NaN
# 20242                                                NaN               NaN
# 20243                                                NaN               NaN
# 20244                                                NaN               NaN
# 20245                                                NaN               NaN
# 20246                                                NaN               NaN
# 20247                                                NaN               NaN
# 20248                                                NaN               NaN
# 20249                                                NaN               NaN
# 21036                                                NaN               NaN
#
#        cover_width cover_height
# 16016          NaN          NaN
# 18609          NaN          NaN
# 18905          NaN          NaN
# 19136          NaN          NaN
# 19488          NaN          NaN
# 20200          NaN          NaN
# 20201          NaN          NaN
# 20202          NaN          NaN
# 20203          NaN          NaN
# 20204          NaN          NaN
# 20205          NaN          NaN
# 20206          NaN          NaN
# 20207          NaN          NaN
# 20208          NaN          NaN
# 20209          NaN          NaN
# 20210          NaN          NaN
# 20211          NaN          NaN
# 20212          NaN          NaN
# 20213          NaN          NaN
# 20214          NaN          NaN
# 20215          NaN          NaN
# 20216          NaN          NaN
# 20217          NaN          NaN
# 20218          NaN          NaN
# 20219          NaN          NaN
# 20220          NaN          NaN
# 20221          NaN          NaN
# 20222          NaN          NaN
# 20223          NaN          NaN
# 20224          NaN          NaN
# 20225          NaN          NaN
# 20226          NaN          NaN
# 20227          NaN          NaN
# 20228          NaN          NaN
# 20229          NaN          NaN
# 20230          NaN          NaN
# 20231          NaN          NaN
# 20232          NaN          NaN
# 20233          NaN          NaN
# 20234          NaN          NaN
# 20235          NaN          NaN
# 20236          NaN          NaN
# 20237          NaN          NaN
# 20238          NaN          NaN
# 20239          NaN          NaN
# 20240          NaN          NaN
# 20241          NaN          NaN
# 20242          NaN          NaN
# 20243          NaN          NaN
# 20244          NaN          NaN
# 20245          NaN          NaN
# 20246          NaN          NaN
# 20247          NaN          NaN
# 20248          NaN          NaN
# 20249          NaN          NaN
# 21036          NaN          NaN
#
# [56 rows x 28 columns]
